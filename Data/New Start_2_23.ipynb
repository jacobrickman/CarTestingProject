# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Out:
# /Users/JacobRickman/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
pressure_df = pd.read_csv('Data_Table.csv')

# %%
event = 'event_1'
lap_1 = pressure_df.loc[pressure_df['event_label'] == event]
lap_1 = lap_1.loc[pressure_df['lap_#'] == 'lap_1']
time = lap_1['time']

lap_1 = lap_1.loc[pressure_df['time'] == time.max()]

lap_1
# Out:
#        port_6     port_7     port_8    port_9    port_10    port_11  \
# 37 -23.219692 -23.411789 -24.165509 -22.95506 -20.217051 -22.817245
#
#       port_12    port_13    port_14    port_15     ...         port_25  \
# 37 -23.186879 -22.443151 -22.662904 -22.786758     ...      -19.644608
#
#      port_26   port_27    port_28    port_29    port_31    port_32    time  \
# 37 -18.91836 -18.30117 -18.335068 -18.350523 -17.536706 -17.649081  757.65
#
#     lap_#  event_label
# 37  lap_1      event_1
#
# [1 rows x 29 columns]

# %%
lap_event_group = pressure_df.groupby(['lap_#', 'event_label'])
start_time = lap_event_group['time'].min()
end_time = lap_event_group['time'].max()

start_time = start_time.get_values()
end_time = end_time.get_values()

#pressures at t = 0
pressure_start_event = pressure_df.loc[pressure_df['time'].isin(start_time)]

#pressures at t = end of the event
pressure_end_event = pressure_df.loc[pressure_df['time'].isin(end_time)]






#start_time = lap_event_group['time'].min() #t = 0
#end_time = lap_event_group['time'].max()   #t = end
#event_length = end_time - start_time       #difference bwtween start and end

#event_length
# Out:
#          port_6     port_7     port_8    port_9    port_10    port_11  \
# 37   -23.219692 -23.411789 -24.165509 -22.95506 -20.217051 -22.817245
# 55   -26.805792 -26.765289 -27.221509 -24.92126 -21.834151 -24.698245
# 93   -15.021182 -15.025489 -15.506409 -14.54616 -13.386151 -14.779445
# 187  -15.021442 -15.211989 -15.506409 -14.54616 -12.306051 -13.753345
# 201  -11.940692 -12.041389 -12.277739 -11.14566  -9.603151 -10.841645
# 216  -14.508192 -15.025489 -15.166909 -13.65126 -11.765851 -13.240305
# 255  -19.975092 -20.430089 -20.769709 -18.48326 -16.084551 -18.028845
# 293  -20.316592 -20.616289 -20.939509 -19.73596 -17.162551 -18.883945
# 321  -23.390492 -24.341089 -24.504509 -23.84876 -20.935751 -22.304445
# 377  -20.145892 -21.174989 -21.788409 -19.91486 -17.342251 -19.055045
# 421  -25.268992 -26.017289 -26.032509 -24.02756 -21.295051 -24.527245
# 437  -29.196792 -30.673189 -31.126509 -29.21106 -24.888151 -27.435245
# ...
